# %%
from PyDictionary import PyDictionary

dictionary = PyDictionary()

def isadjective():
    inputs = ""
    while inputs == "":
        inputs = input("Please input an adjective!")
        inputs = str(inputs)
        if "stop game now" in inputs or "Stop game now" in inputs or "Stop Game Now" in inputs or "Stop Game now" in inputs:
            checker == "Stop Game Now"
            break
        checker = str(dictionary.meaning(inputs))
        if 'Adjective' not in checker:
            inputs = ""
            print ("Your word is not an adjective!")
    return inputs
    
def isverb():
    inputs = ""
    while inputs == "":
        inputs = input("Please input a verb!")
        inputs = str(inputs)
        if "stop game now" in inputs or "Stop game now" in inputs or "Stop Game Now" in inputs or "Stop Game now" in inputs:
            checker = "Stop Game Now"
            break
        checker = str(dictionary.meaning(inputs))
        if 'Verb' not in checker:
            inputs = ""
            print ("Your word is not an verb!")
    return inputs

def isnoun():
    inputs = ""
    while inputs == "":
        inputs = input("Please input a noun!")
        if "stop game now" in inputs or "Stop game now" in inputs or "Stop Game Now" in inputs or "Stop Game now" in inputs:
            checker = "Stop Game Now"
            break
        elif inputs == "" or inputs == " " or inputs == "  " or "   " in inputs:
            print("You must insert a word")
            inputs = ""
    return inputs

def choice():
    choose = ""
    while choose == "":
        accepter = list([str(0),str(1),str(2),str(3),str(4),str(5)])
        choose = input("Now, Please Choose Your Desired Game: (0, 1, 2, 3, 4, or 5)\n1. A ____ Tale\n2. Good ___ Hunting\n3. Wall ____\n4. ____ Club\n5. Inglorious _____\n0. Stop Game Here\n")
        if choose in accepter:
            return int(choose)
        else:
            print ("You must input an integer between 0 and 5!")
            choose = ""

    
def libs1():
    while 1 > 0:
        w0 = str(isnoun())
        if "top" in w0 and "ame" in w0:
            break
        w1 = str(isnoun())
        if "top" in w1 and "ame" in w1:
            break
        w2 = str(isnoun())
        if "top" in w2 and "ame" in w2:
            break
        w3 = str(isadjective())
        if "top" in w3 and "ame" in w3:
            break
        w4 = str(isadjective())
        if "top" in w4 and "ame" in w4:
            break
        w5 = str(isnoun())
        if "top" in w5 and "ame" in w5:
            break
        w6 = str(isnoun())
        if "top" in w6 and "ame" in w6:
            break
        w7 = str(isverb())
        if "top" in w7 and "ame" in w7:
            break
        w8 = str(isadjective())
        if "top" in w8 and "ame" in w8:
            break
        w9 = str(isadjective())
        if "top" in w9 and "ame" in w9:
            break
        w10 = str(isnoun())
        if "top" in w10 and "ame" in w10:
            break
        w11 = str(isverb())
        if "top" in w11 and "ame" in w11:
            break
        w12 = str(isnoun())
        if "top" in w12 and "ame" in w12:
            break
        dialogue = "The " + w0 + " Tale:\n" + w1 + " and my " + w2 + " always said that when I get " + w3 + " I would understand. \nWell, I finally did. I learned something from these " + w4 + " " + w5 + ". \nI learned to give " + w6 +" and get " + w6 + " unconditionally. \nYou just have to " + w7 + " people for what they are, and I learned the greatest gift of all. \nThe " + w8 + " thing in life is " + w9 + " talent, and the " + w10 + " that you make will " + w11 + " your life forever. \nBut you can ask anybody from my " + w12 + ", and they’ll just tell you this is just another " + w0 + " tale."
        print(dialogue)
        print("That Was Fun!")
        break
        
def libs2():
    while 1 > 0:

        w0 = str(isverb())
        if "top" in w0 and "ame" in w0:
            break
        w1 = str(isadjective())
        if "top" in w1 and "ame" in w1:
            break
        w2 = str(isverb())
        if "top" in w2 and "ame" in w2:
            break
        w3 = str(isadjective())
        if "top" in w3 and "ame" in w3:
            break
        w4 = str(isverb())
        if "top" in w4 and "ame" in w4:
            break
        w5 = str(isnoun())
        if "top" in w5 and "ame" in w5:
            break
        w6 = str(isnoun())
        if "top" in w6 and "ame" in w6:
            break
        w7 = str(isnoun())
        if "top" in w7 and "ame" in w7:
            break
        w8 = str(isnoun())
        if "top" in w8 and "ame" in w8:
            break
        w9 = str(isverb())
        if "top" in w9 and "ame" in w9:
            break
        w10 = str(isverb())
        if "top" in w10 and "ame" in w10:
            break
        w11 = str(isverb())
        if "top" in w11 and "ame" in w11:
            break
        w12 = str(isnoun())
        if "top" in w12 and "ame" in w12:
            break
        dialogue = "Your Move, "+ w12 + "\nI "+ w0 +" at you; \nI don’t see an "+ w1 +", "+ w2 +" man; I see a "+ w3 +", "+ w4 +" shitless kid. \nBut you’re a "+ w5 +", Will. No one denies that. No one could possibly understand the depths of you. \nBut you presume to know everything about me because you saw a "+ w6 +"of mine and you ripped my fuckin’ life apart. \nYou’re an "+ w7 +" right? Do you think I’d know the first thing about how hard your life has been, how you feel, who you are because I read "+ w8 +"? \nDoes that encapsulate you? Personally, I don’t give a shit about all that, because you know what? \nI can’t learn anything from you I can’t read in some fuckin’ book. Unless you wanna "+ w9 +" about you, who you are. \nAnd I’m "+ w10 +". I’m in. \nBut you don’t wanna do that, do you, sport? You’re terrified of what you might "+ w11 +". \nYour move, "+ w12 +"."
        print(dialogue)
        print("\nThat Was Fun!\n")
        break

def libs3():
    while 1 > 0:
        w0 = str(isnoun())
        if "top" in w0 and "ame" in w0:
            break
        w1 = str(isnoun())
        if "top" in w1 and "ame" in w1:
            break
        w2 = str(isnoun())
        if "top" in w2 and "ame" in w2:
            break
        w3 = str(isnoun())
        if "top" in w3 and "ame" in w3:
            break
        w4 = str(isverb())
        if "top" in w4 and "ame" in w4:
            break
        w5 = str(isadjective())
        if "top" in w5 and "ame" in w5:
            break
        w6 = str(isverb())
        if "top" in w6 and "ame" in w6:
            break
        w7 = str(isnoun())
        if "top" in w7 and "ame" in w7:
            break
        w8 = str(isnoun())
        if "top" in w8 and "ame" in w8:
            break
        w9 = str(isverb())
        if "top" in w9 and "ame" in w9:
            break
        w10 = str(isnoun())
        if "top" in w10 and "ame" in w10:
            break
        dialogue = "Wall "+ w0 + " \nThe point is, "+ w1 + " and "+ w2 + ", that "+ w3 + ", for lack of a better word, is "+ w4 +". \n"+ w3 + " is right, "+ w3 + " works. "+ w3 + " clarifies, cuts through, and "+w4+ " the essence of the "+ w5 + " spirit. \n"+ w3 + ", in all of its forms; "+ w3 + " for life, for money, for love, knowledge has marked the "+ w6 + "  "+ w7 + "  of mankind. \nAnd "+ w3 + ", you mark my words, will not only save "+ w8 + ", but that other "+ w9 + " "+ w10 + " called the USA. \nThank you very much."
        print(dialogue)
        print("\nThat Was Fun!\n")
        break
        
def libs4():
    while 1 > 0:
        w0 = str(isnoun())
        if "top" in w0 and "ame" in w0:
            break
        w1 = str(isverb())
        if "top" in w1 and "ame" in w1:
            break
        w2 = str(isverb())
        if "top" in w2 and "ame" in w2:
            break
        w3 = str(isverb())
        if "top" in w3 and "ame" in w3:
            break
        w4 = str(isnoun())
        if "top" in w4 and "ame" in w4:
            break
        w5 = str(isnoun())
        if "top" in w5 and "ame" in w5:
            break
        w6 = str(isnoun())
        if "top" in w6 and "ame" in w6:
            break
        w7 = str(isnoun())
        if "top" in w7 and "ame" in w7:
            break
        dialogue = w0 + " Club \nWelcome to "+ w0 + " Club. The first rule of "+ w0 + " Club is: you do not "+ w1 + " about "+ w0 + " Club. The second rule of "+ w0 + " Club is: you DO NOT "+ w1 + " about "+ w0 + " Club! Third rule of "+ w0 + " Club: if someone yells ‘"+ w2 + "’, "+ w3 + " limp, or taps out, the "+ w0 + " is over. Fourth rule: only two "+ w4 + " to a "+ w0 + ". Fifth rule: one "+ w0 + " at a time, fellas. Sixth rule: no "+ w5 + ", no "+ w6 + ". Seventh rule: "+ w0 + " will go on as long as they have to. And the eighth and "+ w7+ " rule: if this is your first night at "+ w0 + " Club, you have to "+ w0 + "."
        print(dialogue)
        print("\nThat Was Fun!\n")
        break
        
def libs5():
    while 1 > 0:
        w0 = str(isnoun())
        if "top" in w0 and "ame" in w0:
            break
        w1 = str(isnoun())
        if "top" in w1 and "ame" in w1:
            break
        w2 = str(isnoun())
        if "top" in w2 and "ame" in w2:
            break
        w3 = str(isverb())
        if "top" in w3 and "ame" in w3:
            break
        w4 = str(isnoun())
        if "top" in w4 and "ame" in w4:
            break
        w5 = str(isadjective())
        if "top" in w5 and "ame" in w5:
            break
        w6 = str(isnoun())
        if "top" in w6 and "ame" in w6:
            break
        w7 = str(isadjective())
        if "top" in w7 and "ame" in w7:
            break
        w8 = str(isnoun())
        if "top" in w8 and "ame" in w8:
            break
        w9 = str(isverb())
        if "top" in w9 and "ame" in w9:
            break
        w10 = str(isnoun())
        if "top" in w10 and "ame" in w10:
            break
        dialogue = "Inglorious "+ w0 + " \nBut I got a word of "+ w1 + " for all you would-be "+ w2 + ". \nWhen you "+ w3 + " my command, you take on "+ w4 + ". A "+ w4 + " you owe me personally. \nEach and every "+ w10 + " under my command owes me 100 "+ w5 + " "+ w6 + ". And I want my "+ w6 + ". \nAnd all y'all will get me 100 "+ w5 + " "+ w6 + " taken from the heads of 100 "+ w7 + " "+ w8 + ". \nOr you will "+ w9 + " tryin'."
        print(dialogue)
        print("\nThat Was Fun!\n")
        break


print("Welcome To The Mad Libs Games!\n The Rules Are Simple: Input The Requested Words, And We'll Take Care Of The Rest! \nIf you would like to stop during the game, type 'Stop Game Here'")
chooser = 10
while chooser != 0:
    chooser = choice()
    if chooser == 1:
        print("You chose 1. A ____ Tale")
        libs1()
        endgame = input("Would You Like To Play Again? (Y/N)")
        if "n" in endgame or "N" in endgame:
            chooser = 0
            break
    if chooser == 2:
        print("You chose 2. Good ___ Hunting")
        libs2()
        endgame = input("Would You Like To Play Again? (Y/N)")
        if "n" in endgame or "N" in endgame:
            chooser = 0
            break
    if chooser == 3:
        print("You chose 3. Wall ____")
        libs3()
        endgame = input("Would You Like To Play Again? (Y/N)")
        if "n" in endgame or "N" in endgame:
            chooser = 0
            break
    if chooser == 4:
        print("You chose 4. ____ Club")
        libs4()
        endgame = input("Would You Like To Play Again? (Y/N)")
        if "n" in endgame or "N" in endgame:
            chooser = 0
            break
    if chooser == 5:
        print("You chose 5. Inglorious _____")
        libs5()
        endgame = input("Would You Like To Play Again? (Y/N)")
        if "n" in endgame or "N" in endgame:
            chooser = 0
            break
print("Let's Play Again Soon!")
# Out:
# Welcome To The Mad Libs Games!
#  The Rules Are Simple: Input The Requested Words, And We'll Take Care Of The Rest!
# If you would like to stop during the game, type 'Stop Game Here'
# Now, Please Choose Your Desired Game: (0, 1, 2, 3, 4, or 5)
# 1. A ____ Tale
# 2. Good ___ Hunting
# 3. Wall ____
# 4. ____ Club
# 5. Inglorious _____
# 0. Stop Game Here
# 1
# You chose 1. A ____ Tale
# Please input a noun!Stop Game Here
# Would You Like To Play Again? (Y/N)n
# Let's Play Again Soon!
